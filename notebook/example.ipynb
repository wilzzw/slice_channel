# %%
import matplotlib.pyplot as plt

from geometry.slices import prot_slices, msms_slices

import numpy as np

t = 883
z = -2
f = 100
lower = 9
upper = 12.75
incr = 0.125

dat = prot_slices(t, probe_radius=0, from_nc=True)

# prot, cylinder, accessible, color_info = dat._zslice(zlevel=z, center=(1.9,5.4), radius=1, frame=f, color=False)
prot, cylinder, accessible, color_info = dat._zslice(zlevel=z, center=(0,0), radius=0.85, frame=f, color=False)
fig, axs = plt.subplots(1,2)
dat.plot_slice(axs[0], prot, cylinder, accessible)
axs[0].set_xlim(-6,6)
axs[0].set_ylim(-6,6)

dat = msms_slices(t, probe_radius=1.4)

# fig, axs = plt.subplots()

prot, cylinder, accessible = dat.zslice(f, z*10, (0,0), 8.5)
dat.plot_slice(axs[1], prot, cylinder, accessible)
axs[1].set_xlim(-60,60)
axs[1].set_ylim(-60,60)
# pore_slice_analysis.slice_df
# Out:
# MSMS 2.6.1 started on LAPTOP-70IB1GOB
# Copyright M.F. Sanner (1994)
# Compilation flags -O2 -DVERBOSE -DTIMING
# INPUT  tmp/883-msms_0.xyzr 19277 spheres 0 collision only, radii  1.200 to  1.800
# PARAM  Probe_radius  1.400 density  1.000 hdensity  3.000
# REDUCED SURFACE ...
#     RS component 0 identified 4898 4872 4873
#     0 free edge(s) found in component 0
#     RS component  #faces  #edges #free_edges  #vertices   genus
#          0       14858    22287          0       6898      266.5
#     Time Reduced Surface real: 0.20 user: 0.20 sys: 0.00
# ANALYTICAL SOLVENT EXCLUDED SURFACE...
#     Component   0
#         Time Surface real: 0.03 user: 0.04 sys: 0.00
# ordonne_arete: warning hole in a reentrant face 24743
#         Time Singularities real: 0.02 user: 0.01 sys: 0.00
#     SES comp.  #fac.  #edg. #s_edg. #vert. #s_vert. R_h C_h genus
#          0    46146  93705   1741   47520     2932   1   2    22
# ANALYTICAL SURFACE AREA :
#     Comp. probe_radius,   reent,    toric,   contact    SES       SAS
#       0       1.400   19039.664 21533.814 15936.330 56509.805 59440.652
# TRIANGULATION...
#     Component 0
#     component#, vertices,  edges,  faces, genus, density
#         0          69369  208233  138822    22     1.228
#         Time Triangulation real: 0.07 user: 0.08 sys: 0.00
# NUMERICAL VOLUMES AND AREA
#     Comp. probe_radius SES_volume SES_area)
#        0      1.40    176092.500  53018.473
#     Total ses_volume: 176092.500
# MSMS terminated normally
# Total Time real: 0.52 user: 0.48 sys: 0.03
# MSMS 2.6.1 started on LAPTOP-70IB1GOB
# Copyright M.F. Sanner (1994)
# Compilation flags -O2 -DVERBOSE -DTIMING
# INPUT  tmp/883-msms_100.xyzr 19277 spheres 0 collision only, radii  1.200 to  1.800
# PARAM  Probe_radius  1.400 density  1.000 hdensity  3.000
# REDUCED SURFACE ...
#     RS component 0 identified 4898 4890 4874
#     6 free edge(s) found in component 0
#     RS component  #faces  #edges #free_edges  #vertices   genus
#          0       15076    22614          6       6988      279
#     Time Reduced Surface real: 0.21 user: 0.20 sys: 0.01
# ANALYTICAL SOLVENT EXCLUDED SURFACE...
#     Component   0
#         Time Surface real: 0.04 user: 0.01 sys: 0.02
# ordonne_arete: warning hole in a reentrant face 10355
# ordonne_arete: warning hole in a reentrant face 13806
#         Time Singularities real: 0.01 user: 0.02 sys: 0.00
#     SES comp.  #fac.  #edg. #s_edg. #vert. #s_vert. R_h C_h genus
#          0    46846  95115   1668   48246     3042   2  15    21
# ANALYTICAL SURFACE AREA :
#     Comp. probe_radius,   reent,    toric,   contact    SES       SAS
#       0       1.400   19191.863 21504.434 15825.031 56521.328 59243.746
# TRIANGULATION...
#     Component 0
#     reentrant faces isolated vertices: 1
# WARNING: geodesic which intersects odd number of edges
#     component#, vertices,  edges,  faces, genus, density
#         0          70204  210732  140488    21     1.242
#         Time Triangulation real: 0.08 user: 0.07 sys: 0.00
# NUMERICAL VOLUMES AND AREA
#     Comp. probe_radius SES_volume SES_area)
#        0      1.40    175556.438  53034.359
#     Total ses_volume: 175556.438
# MSMS terminated normally
# Total Time real: 0.53 user: 0.43 sys: 0.09
# []
# (-60.0, 60.0)
